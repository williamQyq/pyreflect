# %% [markdown]
# # Pyreflect Reflectivity Pipeline Example
#
# This notebook demonstrates the example workflow with clearer, annotated steps. It shows how to go from neutron reflectivity (NR) curves to scattering length density (SLD) profiles using `pyreflect`.

# %% [markdown]
# ## 1. Environment setup
#
# Use the following cells to make sure PyTorch and pyreflect are available. Installation is commented out so you can enable it only if needed.

# %%
# Uncomment if ipykernel is needed in this environment. Skip for windows.

# !curl -fsSL https://raw.githubusercontent.com/williamQyq/pyreflect/main/setup.sh | bash
# Out:
# === Setting up Conda environment: pyreflect ===
# Is Windows: true
# [OK] Conda found: conda 25.11.1
# [INFO] Env 'pyreflect' already exists
# 3 channel Terms of Service accepted
# done
# Channels:
#  - defaults
# Platform: win-64
# done
# done
#
# # All requested packages already installed.
#
# [INFO] Installing scientific dependencies via conda-forge
# 3 channel Terms of Service accepted
# Channels:
#  - conda-forge
#  - defaults
# Platform: win-64
# done
# done
#
# ## Package Plan ##
#
#   environment location: C:\Users\rahej\miniconda3\envs\pyreflect
#
#   added / updated specs:
#     - llvmlite
#     - numba
#     - numpy
#     - refl1d
#     - scipy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2026.2.25          |     pyhd8ed1ab_0         148 KB  conda-forge
#     numba-0.64.0               |  py310h04bad52_0         4.2 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         4.3 MB
#
# The following packages will be UPDATED:
#
#   ca-certificates                       2026.1.4-h4c7d964_0 --> 2026.2.25-h4c7d964_0
#   certifi            pkgs/main/win-64::certifi-2026.01.04-~ --> conda-forge/noarch::certifi-2026.2.25-pyhd8ed1ab_0
#   numba                              0.63.1-py310h04bad52_0 --> 0.64.0-py310h04bad52_0
#
#
#
# Downloading and Extracting Packages: ...working...
# numba-0.64.0         | 4.2 MB    |            |   0%
#
# certifi-2026.2.25    | 148 KB    |            |   0%
#
# certifi-2026.2.25    | 148 KB    | #          |  11%
# numba-0.64.0         | 4.2 MB    |            |   0%
#
# certifi-2026.2.25    | 148 KB    | ########## | 100%
#
# certifi-2026.2.25    | 148 KB    | ########## | 100%
# numba-0.64.0         | 4.2 MB    | ######     |  60%
# numba-0.64.0         | 4.2 MB    | ########## | 100%
# numba-0.64.0         | 4.2 MB    | ########## | 100%
# numba-0.64.0         | 4.2 MB    | ########## | 100%
#
#
#
#                                                       done
# done
# done
# done
# [INFO] Installing remaining Python deps via pip
# Requirement already satisfied: pip in c:\users\rahej\miniconda3\envs\pyreflect\lib\site-packages (26.0.1)
# Looking in indexes: https://test.pypi.org/simple/, https://pypi.org/simple
# Requirement already satisfied: pyreflect==1.4.1 in c:\users\rahej\miniconda3\envs\pyreflect\lib\site-packages (1.4.1)
# Requirement already satisfied: allpairspy<3.0.0,>=2.5.1 in c:\users\rahej\miniconda3\envs\pyreflect\lib\site-packages (from pyreflect==1.4.1) (2.5.1)
# Requirement already satisfied: llvmlite>=0.44.0 in c:\users\rahej\miniconda3\envs\pyreflect\lib\site-packages (from pyreflect==1.4.1) (0.46.0)
# Requirement already satisfied: numba>=0.61.0 in c:\users\rahej\miniconda3\envs\pyreflect\lib\site-packages (from pyreflect==1.4.1) (0.64.0)
# Requirement already satisfied: numpy==2.1.0 in c:\users\rahej\miniconda3\envs\pyreflect\lib\site-packages (from pyreflect==1.4.1) (2.1.0)
# Requirement already satisfied: opencv-python<5.0.0.0,>=4.11.0.86 in c:\users\rahej\miniconda3\envs\pyreflect\lib\site-packages (from pyreflect==1.4.1) (4.13.0.92)
# Requirement already satisfied: pandas<3.0.0,>=2.2.3 in c:\users\rahej\miniconda3\envs\pyreflect\lib\site-packages (from pyreflect==1.4.1) (2.3.3)
# Requirement already satisfied: pyyaml<7.0.0,>=6.0.2 in c:\users\rahej\miniconda3\envs\pyreflect\lib\site-packages (from pyreflect==1.4.1) (6.0.3)
# Requirement already satisfied: refl1d<2.0.0,>=1.0.0a0 in c:\users\rahej\miniconda3\envs\pyreflect\lib\site-packages (from pyreflect==1.4.1) (1.0.0)
# Requirement already satisfied: refnx in c:\users\rahej\miniconda3\envs\pyreflect\lib\site-packages (from pyreflect==1.4.1) (0.1.61)
# Requirement already satisfied: scikit-learn<2.0.0,>=1.6.1 in c:\users\rahej\miniconda3\envs\pyreflect\lib\site-packages (from pyreflect==1.4.1) (1.7.2)
# Requirement already satisfied: scipy<2.0.0,>=1.15.1 in c:\users\rahej\miniconda3\envs\pyreflect\lib\site-packages (from pyreflect==1.4.1) (1.15.3)
# Requirement already satisfied: seaborn<0.14.0,>=0.13.2 in c:\users\rahej\miniconda3\envs\pyreflect\lib\site-packages (from pyreflect==1.4.1) (0.13.2)
# Collecting torch==2.5.1 (from pyreflect==1.4.1)
#   Using cached torch-2.5.1-cp310-cp310-win_amd64.whl.metadata (28 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.67.1 in c:\users\rahej\miniconda3\envs\pyreflect\lib\site-packages (from pyreflect==1.4.1) (4.67.3)
# Requirement already satisfied: typer<0.16.0,>=0.15.1 in c:\users\rahej\miniconda3\envs\pyreflect\lib\site-packages (from pyreflect==1.4.1) (0.15.4)
# Requirement already satisfied: filelock in c:\users\rahej\miniconda3\envs\pyreflect\lib\site-packages (from torch==2.5.1->pyreflect==1.4.1) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\rahej\miniconda3\envs\pyreflect\lib\site-packages (from torch==2.5.1->pyreflect==1.4.1) (4.15.0)
# Requirement already satisfied: networkx in c:\users\rahej\miniconda3\envs\pyreflect\lib\site-packages (from torch==2.5.1->pyreflect==1.4.1) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\rahej\miniconda3\envs\pyreflect\lib\site-packages (from torch==2.5.1->pyreflect==1.4.1) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\rahej\miniconda3\envs\pyreflect\lib\site-packages (from torch==2.5.1->pyreflect==1.4.1) (2025.12.0)
# Collecting sympy==1.13.1 (from torch==2.5.1->pyreflect==1.4.1)
#   Using cached sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\rahej\miniconda3\envs\pyreflect\lib\site-packages (from sympy==1.13.1->torch==2.5.1->pyreflect==1.4.1) (1.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\rahej\miniconda3\envs\pyreflect\lib\site-packages (from pandas<3.0.0,>=2.2.3->pyreflect==1.4.1) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rahej\miniconda3\envs\pyreflect\lib\site-packages (from pandas<3.0.0,>=2.2.3->pyreflect==1.4.1) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\rahej\miniconda3\envs\pyreflect\lib\site-packages (from pandas<3.0.0,>=2.2.3->pyreflect==1.4.1) (2025.3)
# Requirement already satisfied: bumps==1.0.3 in c:\users\rahej\miniconda3\envs\pyreflect\lib\site-packages (from refl1d<2.0.0,>=1.0.0a0->pyreflect==1.4.1) (1.0.3)
# Requirement already satisfied: matplotlib in c:\users\rahej\miniconda3\envs\pyreflect\lib\site-packages (from refl1d<2.0.0,>=1.0.0a0->pyreflect==1.4.1) (3.10.8)
# Requirement already satisfied: periodictable in c:\users\rahej\miniconda3\envs\pyreflect\lib\site-packages (from refl1d<2.0.0,>=1.0.0a0->pyreflect==1.4.1) (1.7.1)
# Requirement already satisfied: orsopy in c:\users\rahej\miniconda3\envs\pyreflect\lib\site-packages (from refl1d<2.0.0,>=1.0.0a0->pyreflect==1.4.1) (1.2.1)
# Requirement already satisfied: h5py in c:\users\rahej\miniconda3\envs\pyreflect\lib\site-packages (from bumps==1.0.3->refl1d<2.0.0,>=1.0.0a0->pyreflect==1.4.1) (3.15.1)
# Requirement already satisfied: dill in c:\users\rahej\miniconda3\envs\pyreflect\lib\site-packages (from bumps==1.0.3->refl1d<2.0.0,>=1.0.0a0->pyreflect==1.4.1) (0.4.1)
# Requirement already satisfied: cloudpickle in c:\users\rahej\miniconda3\envs\pyreflect\lib\site-packages (from bumps==1.0.3->refl1d<2.0.0,>=1.0.0a0->pyreflect==1.4.1) (3.1.2)
# Requirement already satisfied: blinker in c:\users\rahej\miniconda3\envs\pyreflect\lib\site-packages (from bumps==1.0.3->refl1d<2.0.0,>=1.0.0a0->pyreflect==1.4.1) (1.9.0)
# Requirement already satisfied: aiohttp in c:\users\rahej\miniconda3\envs\pyreflect\lib\site-packages (from bumps==1.0.3->refl1d<2.0.0,>=1.0.0a0->pyreflect==1.4.1) (3.13.3)
# Requirement already satisfied: python-socketio in c:\users\rahej\miniconda3\envs\pyreflect\lib\site-packages (from bumps==1.0.3->refl1d<2.0.0,>=1.0.0a0->pyreflect==1.4.1) (5.16.1)
# Requirement already satisfied: plotly in c:\users\rahej\miniconda3\envs\pyreflect\lib\site-packages (from bumps==1.0.3->refl1d<2.0.0,>=1.0.0a0->pyreflect==1.4.1) (6.5.2)
# Requirement already satisfied: mpld3 in c:\users\rahej\miniconda3\envs\pyreflect\lib\site-packages (from bumps==1.0.3->refl1d<2.0.0,>=1.0.0a0->pyreflect==1.4.1) (0.5.12)
# Requirement already satisfied: msgpack in c:\users\rahej\miniconda3\envs\pyreflect\lib\site-packages (from bumps==1.0.3->refl1d<2.0.0,>=1.0.0a0->pyreflect==1.4.1) (1.1.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\rahej\miniconda3\envs\pyreflect\lib\site-packages (from scikit-learn<2.0.0,>=1.6.1->pyreflect==1.4.1) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\rahej\miniconda3\envs\pyreflect\lib\site-packages (from scikit-learn<2.0.0,>=1.6.1->pyreflect==1.4.1) (3.6.0)
# Requirement already satisfied: colorama in c:\users\rahej\miniconda3\envs\pyreflect\lib\site-packages (from tqdm<5.0.0,>=4.67.1->pyreflect==1.4.1) (0.4.6)
# Requirement already satisfied: click<8.2,>=8.0.0 in c:\users\rahej\miniconda3\envs\pyreflect\lib\site-packages (from typer<0.16.0,>=0.15.1->pyreflect==1.4.1) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\rahej\miniconda3\envs\pyreflect\lib\site-packages (from typer<0.16.0,>=0.15.1->pyreflect==1.4.1) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\rahej\miniconda3\envs\pyreflect\lib\site-packages (from typer<0.16.0,>=0.15.1->pyreflect==1.4.1) (14.3.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\rahej\miniconda3\envs\pyreflect\lib\site-packages (from matplotlib->refl1d<2.0.0,>=1.0.0a0->pyreflect==1.4.1) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\rahej\miniconda3\envs\pyreflect\lib\site-packages (from matplotlib->refl1d<2.0.0,>=1.0.0a0->pyreflect==1.4.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\rahej\miniconda3\envs\pyreflect\lib\site-packages (from matplotlib->refl1d<2.0.0,>=1.0.0a0->pyreflect==1.4.1) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\rahej\miniconda3\envs\pyreflect\lib\site-packages (from matplotlib->refl1d<2.0.0,>=1.0.0a0->pyreflect==1.4.1) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\rahej\miniconda3\envs\pyreflect\lib\site-packages (from matplotlib->refl1d<2.0.0,>=1.0.0a0->pyreflect==1.4.1) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\rahej\miniconda3\envs\pyreflect\lib\site-packages (from matplotlib->refl1d<2.0.0,>=1.0.0a0->pyreflect==1.4.1) (11.3.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\rahej\miniconda3\envs\pyreflect\lib\site-packages (from matplotlib->refl1d<2.0.0,>=1.0.0a0->pyreflect==1.4.1) (3.3.2)
# Requirement already satisfied: six>=1.5 in c:\users\rahej\miniconda3\envs\pyreflect\lib\site-packages (from python-dateutil>=2.8.2->pandas<3.0.0,>=2.2.3->pyreflect==1.4.1) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\rahej\miniconda3\envs\pyreflect\lib\site-packages (from rich>=10.11.0->typer<0.16.0,>=0.15.1->pyreflect==1.4.1) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\rahej\miniconda3\envs\pyreflect\lib\site-packages (from rich>=10.11.0->typer<0.16.0,>=0.15.1->pyreflect==1.4.1) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\rahej\miniconda3\envs\pyreflect\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<0.16.0,>=0.15.1->pyreflect==1.4.1) (0.1.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\rahej\miniconda3\envs\pyreflect\lib\site-packages (from aiohttp->bumps==1.0.3->refl1d<2.0.0,>=1.0.0a0->pyreflect==1.4.1) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\rahej\miniconda3\envs\pyreflect\lib\site-packages (from aiohttp->bumps==1.0.3->refl1d<2.0.0,>=1.0.0a0->pyreflect==1.4.1) (1.4.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in c:\users\rahej\miniconda3\envs\pyreflect\lib\site-packages (from aiohttp->bumps==1.0.3->refl1d<2.0.0,>=1.0.0a0->pyreflect==1.4.1) (5.0.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\rahej\miniconda3\envs\pyreflect\lib\site-packages (from aiohttp->bumps==1.0.3->refl1d<2.0.0,>=1.0.0a0->pyreflect==1.4.1) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\rahej\miniconda3\envs\pyreflect\lib\site-packages (from aiohttp->bumps==1.0.3->refl1d<2.0.0,>=1.0.0a0->pyreflect==1.4.1) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\rahej\miniconda3\envs\pyreflect\lib\site-packages (from aiohttp->bumps==1.0.3->refl1d<2.0.0,>=1.0.0a0->pyreflect==1.4.1) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\rahej\miniconda3\envs\pyreflect\lib\site-packages (from aiohttp->bumps==1.0.3->refl1d<2.0.0,>=1.0.0a0->pyreflect==1.4.1) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\rahej\miniconda3\envs\pyreflect\lib\site-packages (from aiohttp->bumps==1.0.3->refl1d<2.0.0,>=1.0.0a0->pyreflect==1.4.1) (1.22.0)
# Requirement already satisfied: idna>=2.0 in c:\users\rahej\miniconda3\envs\pyreflect\lib\site-packages (from yarl<2.0,>=1.17.0->aiohttp->bumps==1.0.3->refl1d<2.0.0,>=1.0.0a0->pyreflect==1.4.1) (3.11)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\rahej\miniconda3\envs\pyreflect\lib\site-packages (from jinja2->torch==2.5.1->pyreflect==1.4.1) (3.0.3)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\rahej\miniconda3\envs\pyreflect\lib\site-packages (from plotly->bumps==1.0.3->refl1d<2.0.0,>=1.0.0a0->pyreflect==1.4.1) (2.16.0)
# Requirement already satisfied: bidict>=0.21.0 in c:\users\rahej\miniconda3\envs\pyreflect\lib\site-packages (from python-socketio->bumps==1.0.3->refl1d<2.0.0,>=1.0.0a0->pyreflect==1.4.1) (0.23.1)
# Requirement already satisfied: python-engineio>=4.11.0 in c:\users\rahej\miniconda3\envs\pyreflect\lib\site-packages (from python-socketio->bumps==1.0.3->refl1d<2.0.0,>=1.0.0a0->pyreflect==1.4.1) (4.13.1)
# Requirement already satisfied: simple-websocket>=0.10.0 in c:\users\rahej\miniconda3\envs\pyreflect\lib\site-packages (from python-engineio>=4.11.0->python-socketio->bumps==1.0.3->refl1d<2.0.0,>=1.0.0a0->pyreflect==1.4.1) (1.1.0)
# Requirement already satisfied: wsproto in c:\users\rahej\miniconda3\envs\pyreflect\lib\site-packages (from simple-websocket>=0.10.0->python-engineio>=4.11.0->python-socketio->bumps==1.0.3->refl1d<2.0.0,>=1.0.0a0->pyreflect==1.4.1) (1.3.2)
# Requirement already satisfied: h11<1,>=0.16.0 in c:\users\rahej\miniconda3\envs\pyreflect\lib\site-packages (from wsproto->simple-websocket>=0.10.0->python-engineio>=4.11.0->python-socketio->bumps==1.0.3->refl1d<2.0.0,>=1.0.0a0->pyreflect==1.4.1) (0.16.0)
# Using cached torch-2.5.1-cp310-cp310-win_amd64.whl (203.1 MB)
# Using cached sympy-1.13.1-py3-none-any.whl (6.2 MB)
# Installing collected packages: sympy, torch
#
#   Attempting uninstall: sympy
#
#     Found existing installation: sympy 1.14.0
#
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#     Uninstalling sympy-1.14.0:
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#       Successfully uninstalled sympy-1.14.0
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#   Attempting uninstall: torch
#    ---------------------------------------- 0/2 [sympy]
#     Found existing installation: torch 2.10.0+cu126
#    ---------------------------------------- 0/2 [sympy]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#     Uninstalling torch-2.10.0+cu126:
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#       Successfully uninstalled torch-2.10.0+cu126
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    ---------------------------------------- 2/2 [torch]
#
# Successfully installed sympy-1.13.1 torch-2.5.1
# [INFO] Attempting to install CUDA-enabled PyTorch (optional)
# 3 channel Terms of Service accepted
# Channels:
#  - pytorch
#  - nvidia
#  - defaults
# Platform: win-64
# done
# done
#
# ## Package Plan ##
#
#   environment location: C:\Users\rahej\miniconda3\envs\pyreflect
#
#   added / updated specs:
#     - pytorch
#     - pytorch-cuda=12.1
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     libuv-1.52.0               |       hd0d7782_0         298 KB
#     ------------------------------------------------------------
#                                            Total:         298 KB
#
# The following NEW packages will be INSTALLED:
#
#   filelock           pkgs/main/win-64::filelock-3.20.3-py310haa95532_0
#   gmp                pkgs/main/win-64::gmp-6.3.0-h537511b_0
#   gmpy2              pkgs/main/win-64::gmpy2-2.2.2-py310h8598115_0
#   libuv              pkgs/main/win-64::libuv-1.52.0-hd0d7782_0
#   mpc                pkgs/main/win-64::mpc-1.3.1-h827c3e9_0
#   mpfr               pkgs/main/win-64::mpfr-4.2.1-h56c3642_0
#   mpmath             pkgs/main/win-64::mpmath-1.3.0-py310haa95532_0
#   networkx           pkgs/main/win-64::networkx-3.4.2-py310haa95532_0
#   pytorch            pytorch/win-64::pytorch-2.2.2-py3.10_cuda12.1_cudnn8_0
#   pytorch-mutex      pytorch/noarch::pytorch-mutex-1.0-cuda
#   sympy              pkgs/main/win-64::sympy-1.14.0-py310haa95532_1
#
#
#
# Downloading and Extracting Packages: ...working...
# libuv-1.52.0         | 298 KB    |            |   0%
# libuv-1.52.0         | 298 KB    | 5          |   5%
# libuv-1.52.0         | 298 KB    | ########## | 100%
# libuv-1.52.0         | 298 KB    | ########## | 100%
#
#  done
# done
# done
# done
# [OK] Installed CUDA-enabled PyTorch via conda (pytorch + pytorch-cuda=12.1).
# Installed kernelspec pyreflect in C:\Users\rahej\AppData\Roaming\jupyter\kernels\pyreflect
# === DONE ===
# Select 'Python (pyreflect)' in Jupyter and you're ready to use pyreflect.
# ==> WARNING: A newer version of conda exists. <==
#     current version: 25.11.1
#     latest version: 26.1.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 25.11.1
#     latest version: 26.1.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.10.0+cu126 requires torch==2.10.0, but you have torch 2.5.1 which is incompatible.
# torchvision 0.25.0+cu126 requires torch==2.10.0, but you have torch 2.5.1 which is incompatible.

# %% [markdown]
# ### 1.1 Install `pyreflect`
#
# `Note`: Install may takes some times and restart Kernel after installation

# %%
# Uncomment if pyreflect is not installed in this environment.
# Installation may takes some times
# !pip install pyreflect-nr
# Out:
# Requirement already satisfied: pyreflect-nr in c:\users\rahej\miniconda3\envs\pyreflect-new\lib\site-packages (1.4.5)
# Requirement already satisfied: allpairspy<3.0.0,>=2.5.1 in c:\users\rahej\miniconda3\envs\pyreflect-new\lib\site-packages (from pyreflect-nr) (2.5.1)
# Requirement already satisfied: llvmlite>=0.44.0 in c:\users\rahej\miniconda3\envs\pyreflect-new\lib\site-packages (from pyreflect-nr) (0.46.0)
# Requirement already satisfied: numba>=0.61.0 in c:\users\rahej\miniconda3\envs\pyreflect-new\lib\site-packages (from pyreflect-nr) (0.63.1)
# Requirement already satisfied: numpy==2.1.0 in c:\users\rahej\miniconda3\envs\pyreflect-new\lib\site-packages (from pyreflect-nr) (2.1.0)
# Requirement already satisfied: opencv-python<5.0.0.0,>=4.11.0.86 in c:\users\rahej\miniconda3\envs\pyreflect-new\lib\site-packages (from pyreflect-nr) (4.13.0.92)
# Requirement already satisfied: pandas<3.0.0,>=2.2.3 in c:\users\rahej\miniconda3\envs\pyreflect-new\lib\site-packages (from pyreflect-nr) (2.3.3)
# Requirement already satisfied: pyyaml<7.0.0,>=6.0.2 in c:\users\rahej\miniconda3\envs\pyreflect-new\lib\site-packages (from pyreflect-nr) (6.0.3)
# Requirement already satisfied: refl1d<2.0.0,>=1.0.0a0 in c:\users\rahej\miniconda3\envs\pyreflect-new\lib\site-packages (from pyreflect-nr) (1.0.0)
# Requirement already satisfied: refnx in c:\users\rahej\miniconda3\envs\pyreflect-new\lib\site-packages (from pyreflect-nr) (0.1.61)
# Requirement already satisfied: scikit-learn<2.0.0,>=1.6.1 in c:\users\rahej\miniconda3\envs\pyreflect-new\lib\site-packages (from pyreflect-nr) (1.7.2)
# Requirement already satisfied: scipy<2.0.0,>=1.15.1 in c:\users\rahej\miniconda3\envs\pyreflect-new\lib\site-packages (from pyreflect-nr) (1.15.2)
# Requirement already satisfied: seaborn<0.14.0,>=0.13.2 in c:\users\rahej\miniconda3\envs\pyreflect-new\lib\site-packages (from pyreflect-nr) (0.13.2)
# Requirement already satisfied: torch==2.5.1 in c:\users\rahej\miniconda3\envs\pyreflect-new\lib\site-packages (from pyreflect-nr) (2.5.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.67.1 in c:\users\rahej\miniconda3\envs\pyreflect-new\lib\site-packages (from pyreflect-nr) (4.67.3)
# Requirement already satisfied: typer<0.16.0,>=0.15.1 in c:\users\rahej\miniconda3\envs\pyreflect-new\lib\site-packages (from pyreflect-nr) (0.15.4)
# Requirement already satisfied: filelock in c:\users\rahej\miniconda3\envs\pyreflect-new\lib\site-packages (from torch==2.5.1->pyreflect-nr) (3.24.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\rahej\miniconda3\envs\pyreflect-new\lib\site-packages (from torch==2.5.1->pyreflect-nr) (4.15.0)
# Requirement already satisfied: networkx in c:\users\rahej\miniconda3\envs\pyreflect-new\lib\site-packages (from torch==2.5.1->pyreflect-nr) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\rahej\miniconda3\envs\pyreflect-new\lib\site-packages (from torch==2.5.1->pyreflect-nr) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\rahej\miniconda3\envs\pyreflect-new\lib\site-packages (from torch==2.5.1->pyreflect-nr) (2026.2.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\rahej\miniconda3\envs\pyreflect-new\lib\site-packages (from torch==2.5.1->pyreflect-nr) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\rahej\miniconda3\envs\pyreflect-new\lib\site-packages (from sympy==1.13.1->torch==2.5.1->pyreflect-nr) (1.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\rahej\miniconda3\envs\pyreflect-new\lib\site-packages (from pandas<3.0.0,>=2.2.3->pyreflect-nr) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rahej\miniconda3\envs\pyreflect-new\lib\site-packages (from pandas<3.0.0,>=2.2.3->pyreflect-nr) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\rahej\miniconda3\envs\pyreflect-new\lib\site-packages (from pandas<3.0.0,>=2.2.3->pyreflect-nr) (2025.3)
# Requirement already satisfied: bumps==1.0.3 in c:\users\rahej\miniconda3\envs\pyreflect-new\lib\site-packages (from refl1d<2.0.0,>=1.0.0a0->pyreflect-nr) (1.0.3)
# Requirement already satisfied: matplotlib in c:\users\rahej\miniconda3\envs\pyreflect-new\lib\site-packages (from refl1d<2.0.0,>=1.0.0a0->pyreflect-nr) (3.10.8)
# Requirement already satisfied: periodictable in c:\users\rahej\miniconda3\envs\pyreflect-new\lib\site-packages (from refl1d<2.0.0,>=1.0.0a0->pyreflect-nr) (1.7.1)
# Requirement already satisfied: orsopy in c:\users\rahej\miniconda3\envs\pyreflect-new\lib\site-packages (from refl1d<2.0.0,>=1.0.0a0->pyreflect-nr) (1.2.1)
# Requirement already satisfied: h5py in c:\users\rahej\miniconda3\envs\pyreflect-new\lib\site-packages (from bumps==1.0.3->refl1d<2.0.0,>=1.0.0a0->pyreflect-nr) (3.15.1)
# Requirement already satisfied: dill in c:\users\rahej\miniconda3\envs\pyreflect-new\lib\site-packages (from bumps==1.0.3->refl1d<2.0.0,>=1.0.0a0->pyreflect-nr) (0.4.1)
# Requirement already satisfied: cloudpickle in c:\users\rahej\miniconda3\envs\pyreflect-new\lib\site-packages (from bumps==1.0.3->refl1d<2.0.0,>=1.0.0a0->pyreflect-nr) (3.1.2)
# Requirement already satisfied: blinker in c:\users\rahej\miniconda3\envs\pyreflect-new\lib\site-packages (from bumps==1.0.3->refl1d<2.0.0,>=1.0.0a0->pyreflect-nr) (1.9.0)
# Requirement already satisfied: aiohttp in c:\users\rahej\miniconda3\envs\pyreflect-new\lib\site-packages (from bumps==1.0.3->refl1d<2.0.0,>=1.0.0a0->pyreflect-nr) (3.13.3)
# Requirement already satisfied: python-socketio in c:\users\rahej\miniconda3\envs\pyreflect-new\lib\site-packages (from bumps==1.0.3->refl1d<2.0.0,>=1.0.0a0->pyreflect-nr) (5.16.1)
# Requirement already satisfied: plotly in c:\users\rahej\miniconda3\envs\pyreflect-new\lib\site-packages (from bumps==1.0.3->refl1d<2.0.0,>=1.0.0a0->pyreflect-nr) (6.5.2)
# Requirement already satisfied: mpld3 in c:\users\rahej\miniconda3\envs\pyreflect-new\lib\site-packages (from bumps==1.0.3->refl1d<2.0.0,>=1.0.0a0->pyreflect-nr) (0.5.12)
# Requirement already satisfied: msgpack in c:\users\rahej\miniconda3\envs\pyreflect-new\lib\site-packages (from bumps==1.0.3->refl1d<2.0.0,>=1.0.0a0->pyreflect-nr) (1.1.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\rahej\miniconda3\envs\pyreflect-new\lib\site-packages (from scikit-learn<2.0.0,>=1.6.1->pyreflect-nr) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\rahej\miniconda3\envs\pyreflect-new\lib\site-packages (from scikit-learn<2.0.0,>=1.6.1->pyreflect-nr) (3.6.0)
# Requirement already satisfied: colorama in c:\users\rahej\miniconda3\envs\pyreflect-new\lib\site-packages (from tqdm<5.0.0,>=4.67.1->pyreflect-nr) (0.4.6)
# Requirement already satisfied: click<8.2,>=8.0.0 in c:\users\rahej\miniconda3\envs\pyreflect-new\lib\site-packages (from typer<0.16.0,>=0.15.1->pyreflect-nr) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\rahej\miniconda3\envs\pyreflect-new\lib\site-packages (from typer<0.16.0,>=0.15.1->pyreflect-nr) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\rahej\miniconda3\envs\pyreflect-new\lib\site-packages (from typer<0.16.0,>=0.15.1->pyreflect-nr) (14.3.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\rahej\miniconda3\envs\pyreflect-new\lib\site-packages (from matplotlib->refl1d<2.0.0,>=1.0.0a0->pyreflect-nr) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\rahej\miniconda3\envs\pyreflect-new\lib\site-packages (from matplotlib->refl1d<2.0.0,>=1.0.0a0->pyreflect-nr) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\rahej\miniconda3\envs\pyreflect-new\lib\site-packages (from matplotlib->refl1d<2.0.0,>=1.0.0a0->pyreflect-nr) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\rahej\miniconda3\envs\pyreflect-new\lib\site-packages (from matplotlib->refl1d<2.0.0,>=1.0.0a0->pyreflect-nr) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\rahej\miniconda3\envs\pyreflect-new\lib\site-packages (from matplotlib->refl1d<2.0.0,>=1.0.0a0->pyreflect-nr) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\rahej\miniconda3\envs\pyreflect-new\lib\site-packages (from matplotlib->refl1d<2.0.0,>=1.0.0a0->pyreflect-nr) (11.3.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\rahej\miniconda3\envs\pyreflect-new\lib\site-packages (from matplotlib->refl1d<2.0.0,>=1.0.0a0->pyreflect-nr) (3.3.2)
# Requirement already satisfied: six>=1.5 in c:\users\rahej\miniconda3\envs\pyreflect-new\lib\site-packages (from python-dateutil>=2.8.2->pandas<3.0.0,>=2.2.3->pyreflect-nr) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\rahej\miniconda3\envs\pyreflect-new\lib\site-packages (from rich>=10.11.0->typer<0.16.0,>=0.15.1->pyreflect-nr) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\rahej\miniconda3\envs\pyreflect-new\lib\site-packages (from rich>=10.11.0->typer<0.16.0,>=0.15.1->pyreflect-nr) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\rahej\miniconda3\envs\pyreflect-new\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<0.16.0,>=0.15.1->pyreflect-nr) (0.1.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\rahej\miniconda3\envs\pyreflect-new\lib\site-packages (from aiohttp->bumps==1.0.3->refl1d<2.0.0,>=1.0.0a0->pyreflect-nr) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\rahej\miniconda3\envs\pyreflect-new\lib\site-packages (from aiohttp->bumps==1.0.3->refl1d<2.0.0,>=1.0.0a0->pyreflect-nr) (1.4.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in c:\users\rahej\miniconda3\envs\pyreflect-new\lib\site-packages (from aiohttp->bumps==1.0.3->refl1d<2.0.0,>=1.0.0a0->pyreflect-nr) (5.0.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\rahej\miniconda3\envs\pyreflect-new\lib\site-packages (from aiohttp->bumps==1.0.3->refl1d<2.0.0,>=1.0.0a0->pyreflect-nr) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\rahej\miniconda3\envs\pyreflect-new\lib\site-packages (from aiohttp->bumps==1.0.3->refl1d<2.0.0,>=1.0.0a0->pyreflect-nr) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\rahej\miniconda3\envs\pyreflect-new\lib\site-packages (from aiohttp->bumps==1.0.3->refl1d<2.0.0,>=1.0.0a0->pyreflect-nr) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\rahej\miniconda3\envs\pyreflect-new\lib\site-packages (from aiohttp->bumps==1.0.3->refl1d<2.0.0,>=1.0.0a0->pyreflect-nr) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\rahej\miniconda3\envs\pyreflect-new\lib\site-packages (from aiohttp->bumps==1.0.3->refl1d<2.0.0,>=1.0.0a0->pyreflect-nr) (1.22.0)
# Requirement already satisfied: idna>=2.0 in c:\users\rahej\miniconda3\envs\pyreflect-new\lib\site-packages (from yarl<2.0,>=1.17.0->aiohttp->bumps==1.0.3->refl1d<2.0.0,>=1.0.0a0->pyreflect-nr) (3.11)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\rahej\miniconda3\envs\pyreflect-new\lib\site-packages (from jinja2->torch==2.5.1->pyreflect-nr) (3.0.3)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\rahej\miniconda3\envs\pyreflect-new\lib\site-packages (from plotly->bumps==1.0.3->refl1d<2.0.0,>=1.0.0a0->pyreflect-nr) (2.17.0)
# Requirement already satisfied: bidict>=0.21.0 in c:\users\rahej\miniconda3\envs\pyreflect-new\lib\site-packages (from python-socketio->bumps==1.0.3->refl1d<2.0.0,>=1.0.0a0->pyreflect-nr) (0.23.1)
# Requirement already satisfied: python-engineio>=4.11.0 in c:\users\rahej\miniconda3\envs\pyreflect-new\lib\site-packages (from python-socketio->bumps==1.0.3->refl1d<2.0.0,>=1.0.0a0->pyreflect-nr) (4.13.1)
# Requirement already satisfied: simple-websocket>=0.10.0 in c:\users\rahej\miniconda3\envs\pyreflect-new\lib\site-packages (from python-engineio>=4.11.0->python-socketio->bumps==1.0.3->refl1d<2.0.0,>=1.0.0a0->pyreflect-nr) (1.1.0)
# Requirement already satisfied: wsproto in c:\users\rahej\miniconda3\envs\pyreflect-new\lib\site-packages (from simple-websocket>=0.10.0->python-engineio>=4.11.0->python-socketio->bumps==1.0.3->refl1d<2.0.0,>=1.0.0a0->pyreflect-nr) (1.3.2)
# Requirement already satisfied: h11<1,>=0.16.0 in c:\users\rahej\miniconda3\envs\pyreflect-new\lib\site-packages (from wsproto->simple-websocket>=0.10.0->python-engineio>=4.11.0->python-socketio->bumps==1.0.3->refl1d<2.0.0,>=1.0.0a0->pyreflect-nr) (0.16.0)

# %%
# !pip show pyreflect-nr
# Out:
# Name: pyreflect-nr
# Version: 1.4.5
# Summary: The package tool for neutron reflectivity analysis
# Home-page: https://github.com/williamQyq/pyreflect
# Author: Yuqing Qiao
# Author-email: qiao.yuqi@northeastern.edu
# License-Expression: MIT
# Location: c:\users\rahej\miniconda3\envs\pyreflect-new\lib\site-packages
# Editable project location: C:\Users\rahej\Documents\Programming\Northeastern\CS 2535\pyreflect-new-overfitting
# Requires: allpairspy, llvmlite, numba, numpy, opencv-python, pandas, pyyaml, refl1d, refnx, scikit-learn, scipy, seaborn, torch, tqdm, typer
# Required-by:

# %%
import platform, sys, importlib

def safe_version(pkg):
    try:
        module = importlib.import_module(pkg)
        return getattr(module, "__version__", "unknown")
    except ModuleNotFoundError:
        return "not installed"

print(f"Python: {sys.version.split()[0]} ({platform.system()} {platform.release()})")
print(f"PyTorch: {safe_version('torch')}")

try:
    import torch
    print("CUDA available:", torch.cuda.is_available())
    if torch.cuda.is_available():
        print("CUDA device:", torch.cuda.get_device_name(0))
except ModuleNotFoundError:
    pass
# Out:
# Python: 3.10.19 (Windows 10)
# PyTorch: 2.5.1+cpu
# CUDA available: False

# %% [markdown]
# ## 2. Paths and data overview
#
# We keep all paths together for clarity. The repo already ships generated train/test splits and a pretrained model so you can run inference quickly.

# %%
from pathlib import Path
import numpy as np
from pprint import pprint

ROOT = Path("C:/Users/rahej/Documents/Programming/Northeastern/CS 2535/pyreflect-new-overfitting/experiments/best_model_30k_6L_0.107D")

TRAIN_NR   = ROOT / "data/curves/nr_train.npy"
TRAIN_SLD  = ROOT / "data/curves/sld_train.npy"
TEST_NR    = ROOT / "data/curves/nr_train.npy"
TEST_SLD   = ROOT / "data/curves/sld_train.npy"
PRETRAINED_MODEL     = ROOT / "trained_model.pth"
NORMALIZATION_STAT   = ROOT / "data/normalization_stat.npy"

for path in [TRAIN_NR, TRAIN_SLD, TEST_NR, TEST_SLD, NORMALIZATION_STAT]:
    assert path.exists(), f"Missing file: {path}"
print("All expected files are present.")
# Out:
# All expected files are present.

# %% [markdown]
# ## 2.1 Configuration Overview
# We load and inspect the NR → SLD pipeline configuration:
#
# Load settings.yml, then override the paths and hyperparameters to match the data above. Keep epochs small for a quick demo;

# %%
# import sys
# !{sys.executable} -m pyreflect init --force

# %%
import pyreflect
from pyreflect.config import load_config
from pyreflect.input import NRSLDDataProcessor
import pyreflect.pipelines.reflectivity_pipeline as workflow
from pprint import pprint
import numpy as np

root = str(ROOT)  # points to experiments/best_model_30k_6L_0.107D where settings.yml lives
config = pyreflect.config.load_config(root)

pprint(config['nr_predict_sld'])
# Out:
# Selected device for model training: cpu
# {'file': {'nr_train': 'data/curves/nr_train.npy',
#           'sld_train': 'data/curves/sld_train.npy'},
#  'models': {'batch_size': 64,
#             'dropout': 0.107,
#             'epochs': 20,
#             'layers': 6,
#             'model': 'data/trained_nr_sld_model.pth',
#             'normalization_stats': 'data/normalization_stat.npy',
#             'num_curves': 30000,
#             'num_film_layers': 5}}

# %% [markdown]
# ## 3. Dataset Preparation
# - We load pre-generated synthetic datasets (already shuffled):
#     - NR curves: shape (N, 2, 308) → (Q, R)
#     - SLD profiles: shape (N, 2, 900) → (z, ρ)

# %%
dproc = NRSLDDataProcessor(TRAIN_NR,TRAIN_SLD).load_data()
dproc._nr_arr.shape, dproc._sld_arr.shape
# Out:
# ((30000, 2, 308), (30000, 2, 900))

# %% [markdown]
# ## 4. Model Architecture & Training
# ### 4.1 Training Configuration

# %%
model_config = config["nr_predict_sld"]["models"]
# the # of material layers
model_config["num_film_layers"] = 5
model_config["dropout"] = 0.107
model_config["epochs"] = 3
model_config["model"]=PRETRAINED_MODEL
# cnn model layers
model_config["layers"]=6
model_config["normalization_stats"] = NORMALIZATION_STAT


file_config = config["nr_predict_sld"]["file"]
# training X
file_config["nr_train"] = TRAIN_NR
# training y
file_config["sld_train"] = TRAIN_SLD


from pyreflect.models.config import NRSLDModelTrainerParams
# Hyperparameters for training
trainer_params = NRSLDModelTrainerParams(root,_config = config)

# %% [markdown]
# ### 4.2 Prepare a lightweight training set
# The full training split is large; to keep the example snappy we take a small slice. Adjust train_slice as needed.

# %%
import pyreflect.pipelines.reflectivity_pipeline as workflow

# Use the NRSLDDataProcessor to handle pre-processing
X_train, y_train = workflow.preprocess(dproc,trainer_params.normalization_stats)

# %% [markdown]
# ## 5. Train or load a model
#
# Set `use_pretrained=True` to skip training and use the bundled weights. Set it to `False` to run a short training session with the sliced data.
#
# The trained model is automatically saved for reuse. The save model path will be `PRETRAINED_MODEL`

# %%
use_pretrained = True

pipeline = workflow.ReflectivityPipeline(None, trainer_params)

if use_pretrained:
    model = pipeline.load_model(str(PRETRAINED_MODEL))
else:
    # training model
    model = workflow.train_nr_predict_sld_model(X_train, y_train, trainer_params, auto_save=True)

norm_stats = workflow.load_normalization_stat(str(NORMALIZATION_STAT))
# Out:
# C:\Users\rahej\Documents\Programming\Northeastern\CS 2535\pyreflect-new-overfitting\src\pyreflect\pipelines\reflectivity_pipeline.py:245: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(Path(model_path), map_location=DEVICE)
# Loaded NR predict SLD model from: C:\Users\rahej\Documents\Programming\Northeastern\CS 2535\pyreflect-new-overfitting\experiments\best_model_30k_6L_0.107D\trained_model.pth

# %% [markdown]
# ## 6. Run inference on a test batch
#
# We take a handful of test NR curves and predict their SLD profiles.

# %%
test_batch = 10
test_proc = NRSLDDataProcessor(TEST_NR, TEST_SLD).load_data()
nr_batch = test_proc._nr_arr[:test_batch]
true_sld = test_proc._sld_arr[:test_batch]

y_pred = pipeline.predict_sld(nr_batch, norm_stats, model)
print("Predictions shape:", np.asarray(y_pred).shape)
# Out:
# Predicted SLD shape: (10, 2, 900)
# Predictions shape: (10, 2, 900)

# %% [markdown]
# ## 7. Helper Function (Optional) — for Experimental Data
#
# The experimental SLD–depth profile must be flipped so that it is oriented from the silicon substrate toward the air interface, ensuring consistency with the model’s prediction format.
# Belows are helper function to do the flip and align points.

# %%
# from pyreflect.pipelines import reverse_y_order, find_substrate_critical_idx, align_points

# usage:
# Flip SLD y from left to right, substrate to air direction
# reverse_y_order(sld_array)

# Align B to A
# aligned_arr = align_points(a,b)

# %% [markdown]
# ## 8. Compute Neutron Reflectivity (NR) from SLD
#
# This section defines a helper function to compute neutron reflectivity directly from the predicted SLD profile, enabling comparison with the ground-truth reflectivity to verify the training result.

# %%
import numpy as np
import pyreflect
from pyreflect.pipelines import compute_nr_from_sld

computed_nr = []

for i in range(test_batch):
    profile = np.asarray(y_pred[i])

    Q,R = compute_nr_from_sld(profile)
    # Stack Q and R → (2, nQ)
    QR = np.stack([Q, R], axis=0)
    computed_nr.append(QR)

# Stack samples → (10, 2, nQ)
computed_nr = np.stack(computed_nr)

# %% [markdown]
# ## 9. Visualization: Prediction vs GroundTruth -- NR & SLD Side-by-Side
#
# - Left: Experimental NR vs NR recomputed from predicted SLD
#
# - Right: Ground-truth SLD vs predicted SLD (with/without dropout)

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

mpl.rcParams["font.family"] = "DejaVu Sans"   # or "Arial"

def plot_experiment_results(expt_nr_data, expt_sld_data=None,
                            computed_nr_data=None, predicted_sld_data=None):
    """
    Publication-quality plot for AAAI paper: NR & SLD side-by-side.
    """

    # --- Matplotlib style for paper ---
    mpl.rcParams.update({
        "font.size": 8,              # base font size
        "axes.labelsize": 9,
        "axes.titlesize": 9,
        "legend.fontsize": 7,
        "xtick.labelsize": 7,
        "ytick.labelsize": 7,
        "lines.linewidth": 1.3,
        "figure.dpi": 300,
    })

    fig, axes = plt.subplots(1, 2, figsize=(6.8, 2.6))  # fits in 2-column width

    # --- Left: Reflectivity (NR) ---
    axes[0].plot(expt_nr_data[0], expt_nr_data[1],
                 color="black", alpha=0.8, linestyle="-",linewidth=2,
                 label="GroundTruth")
    if computed_nr_data is not None:
        axes[0].plot(computed_nr_data[0], computed_nr_data[1],
                     color="black", label="Computed NR", linestyle="--",linewidth=1.3)

    axes[0].set_xlabel("Q (Å⁻¹)")
    axes[0].set_ylabel("Reflectivity NR")
    axes[0].set_yscale("log")

    # Legend inside top-right, small box
    axes[0].legend(frameon=False, loc="lower left", handlelength=2.5)


    # --- Right: SLD Profiles ---
    if expt_sld_data is not None:
        axes[1].plot(expt_sld_data[0], expt_sld_data[1],
                     color="black", alpha=0.8, linestyle="-",linewidth=2,
                     label="GroundTruth")
    if predicted_sld_data is not None:
        axes[1].plot(predicted_sld_data[0], predicted_sld_data[1],
                     color="red", linestyle="--", label="No Dropout")

    # if dropout_sld_data is not None:
    #     axes[1].plot(dropout_sld_data[0], dropout_sld_data[1],
    #                  color="blue", linestyle="--", label="Dropout")

    axes[1].set_xlabel("Depth (Å)")
    axes[1].set_ylabel("SLD (×10⁻⁶ Å⁻²)")

    axes[1].legend(frameon=False, loc="lower left", handlelength=2.5)

    # --- Remove titles (paper captions describe them) ---
    for ax in axes:
        ax.set_title("")
        ax.tick_params(direction="in", length=2.5)

    plt.tight_layout(pad=1.0, w_pad=1.4)
    plt.show()
    return fig

# %%
# %matplotlib inline

test_batch = 10
test_proc = NRSLDDataProcessor(TEST_NR, TEST_SLD).load_data()
nr_batch = test_proc._nr_arr[:test_batch]
true_sld = test_proc._sld_arr[:test_batch]

for i in range(test_batch):
    fig = plot_experiment_results(
        nr_batch[i],
        expt_sld_data=true_sld[i],
        computed_nr_data=computed_nr[i],
        predicted_sld_data=y_pred[i])
